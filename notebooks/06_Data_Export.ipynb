# %%
import pandas as pd

# Forecast data manually create karo
forecast_data = {
    'Month': ['January 2018', 'February 2018', 'March 2018'],
    'Forecast_Sales': [70398, 63344, 58498],
    'Type': ['Forecast', 'Forecast', 'Forecast']
}

forecast_df = pd.DataFrame(forecast_data)
forecast_df.to_csv('../data/forecast.csv', index=False)
print("✅ Forecast CSV saved!")
# Out:
# ✅ Forecast CSV saved!

# %%
# Anomaly data
anomaly_data = {
    'Month': ['November 2017'],
    'Sales': [118448],
    'Type': ['Anomaly'],
    'Reason': ['Holiday Season + Black Friday']
}

anomaly_df = pd.DataFrame(anomaly_data)
anomaly_df.to_csv('../data/anomaly.csv', index=False)
print("✅ Anomaly CSV saved!")
# Out:
# ✅ Anomaly CSV saved!
